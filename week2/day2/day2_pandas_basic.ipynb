# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/battery_capacity.csv")
df
# Out:
#    cycle  capacity
# 0      1      2.50
# 1      2      2.47
# 2      3      2.44
# 3      4      2.40
# 4      5      2.35

# %%
df.head()
# Out:
#    cycle  capacity
# 0      1      2.50
# 1      2      2.47
# 2      3      2.44
# 3      4      2.40
# 4      5      2.35

# %%
df.tail()
# Out:
#    cycle  capacity
# 0      1      2.50
# 1      2      2.47
# 2      3      2.44
# 3      4      2.40
# 4      5      2.35

# %%
df.shape
# Out:
# (5, 2)

# %%
df.columns
# Out:
# Index(['cycle', 'capacity'], dtype='object')

# %%
df.head()
df.tail()
df.shape
df.columns
# Out:
# Index(['cycle', 'capacity'], dtype='object')

# %%
df["capacity"]
# Out:
# 0    2.50
# 1    2.47
# 2    2.44
# 3    2.40
# 4    2.35
# Name: capacity, dtype: float64

# %%
capacities = df["capacity"].values
capacities
# Out:
# array([2.5 , 2.47, 2.44, 2.4 , 2.35])

# %%
df[["cycle", "capacity"]]
# Out:
#    cycle  capacity
# 0      1      2.50
# 1      2      2.47
# 2      3      2.44
# 3      4      2.40
# 4      5      2.35

# %%
df["capacity"].mean()
# Out:
# np.float64(2.432)

# %%
df["capacity"].min()
# Out:
# 2.35

# %%
initial_capacity = df["capacity"].iloc[0]
df["capacity_fade_percent"] = ((initial_capacity - df["capacity"])/ initial_capacity * 100)
df
# Out:
#    cycle  capacity  capacity_fade_percent
# 0      1      2.50                    0.0
# 1      2      2.47                    1.2
# 2      3      2.44                    2.4
# 3      4      2.40                    4.0
# 4      5      2.35                    6.0

# %%
df[df["capacity_fade_percent"]>5]
# Out:
#    cycle  capacity  capacity_fade_percent
# 4      5      2.35                    6.0

# %%
df.to_csv("../../data/battery_capacity_with_fade.csv", index=False)
